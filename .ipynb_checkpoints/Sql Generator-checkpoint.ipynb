# %%
import pandas

# %%
a = pandas.read_csv("6M Partition/1820.csv")
a.head()
# Out:
#    textID    #words genre  year                                    title  \
# 0    7562   45,611    FIC  1820                       The poetical works
# 1    8735   12,558    FIC  1820                     The Mountain Torrent
# 2    8900    3,363    FIC  1820              The Irish Exiles in America
# 3    8901    1,303    FIC  1820  Lady Jane Gray and Lord Guilford Dudley
# 4    8902    3,040    FIC  1820                                    Naomi
#
#                                               author Publication information  \
# 0                          Trumbull, John, 1750-1831                     NaN
# 1  Judah, Samuel B. H. (Samuel Benjamin Helbert),...                     NaN
# 2                                     Selden, Almira                     NaN
# 3                                     Selden, Almira                     NaN
# 4                                     Selden, Almira                     NaN
#
#   Library of Congress classification (NF) FIXED
# 0                                     NaN     n
# 1                                     NaN     n
# 2                                     NaN     n
# 3                                     NaN     n
# 4                                     NaN     n

# %%
genre = ["FIC", "NF", "MAG"]
years = [1820, 1830, 1840, 1850, 1860, 1870, 1880, 1890, 1900, 1910, 1920, 1930, 1940, 1950, 1960, 1970, 1980, 1990, 2000]
verb = ['make', 'take', 'give']

# %%
for i in genre:
    print(i)
# Out:
# FIC
# NF
# MAG

# %%
f=open("fullSelect.sql", "a+")
for v in verb:
    for i in years:
        a = pandas.read_csv("6M Partition/" + str(i) + ".csv")
        for j in genre:
            sqlQuery = ""
            sqlSource = ""
            print("\n", "--", i, j, v, "\n")
            b = a.loc[a['genre'] == j]
            for row in b.iterrows():
                sqlSource = sqlSource + "s.textid = " + str(row[1][0]) + " or "
            sqlSource = sqlSource[:-3]
            sqlQuery = """
COPY (
SELECT count(*), lemma from (
SELECT c.w2 FROM wordlines as c, lexicon as l , sources as s
    where l.lemma like \'""" + v + "\'" + """
    and c.w1 = l.wid 
    and c.source = s.textid
    and s.year BETWEEN """ + str(i) + " and " + str(i + 9) + """
    and (
    """ + sqlSource + ")" + """
UNION ALL """ + """
SELECT c.w3 FROM wordlines as c, lexicon as l , sources as s
    where l.lemma like \'""" + v + "\'" + """
    and c.w1 = l.wid 
    and c.source = s.textid
    and s.year BETWEEN """ + str(i) + " and " + str(i + 9) + """
    and (
    """ + sqlSource + ")" + """
UNION ALL """ + """
SELECT c.w4 FROM wordlines as c, lexicon as l , sources as s
    where l.lemma like \'""" + v + "\'" + """
    and c.w1 = l.wid 
    and c.source = s.textid
    and s.year BETWEEN """ + str(i) + " and " + str(i + 9) + """
    and (
    """ + sqlSource + ")" + """
UNION ALL """ + """
SELECT c.w5 FROM wordlines as c, lexicon as l , sources as s
    where l.lemma like \'""" + v + "\'" + """
    and c.w1 = l.wid 
    and c.source = s.textid
    and s.year BETWEEN """ + str(i) + " and " + str(i + 9) + """
    and (
    """ + sqlSource + ")" + """
UNION ALL """ + """
SELECT c.w6 FROM wordlines as c, lexicon as l , sources as s
    where l.lemma like \'""" + v + "\'" + """
    and c.w1 = l.wid 
    and c.source = s.textid
    and s.year BETWEEN """ + str(i) + " and " + str(i + 9) + """
    and (
    """ + sqlSource + ")" + """
    a, lexicon b where 
        (
            b.pos like '%nn@%' or b.pos like '%nn\%%' or b.pos like 'nn'
            or b.pos like '%nn1%' or b.pos like '%nn2%'
        ) 
        and a.w2 = b.wid group by b.lemma order by count(*) desc 
) TO """ + "\'/var/lib/postgresql/" + v + str(i) + j + ".csv\' CSV HEADER;"
            
            f.write(sqlQuery)
            
f.close()
# Out:
#  -- 1820 FIC make
#
#
#  -- 1820 NF make
#
#
#  -- 1820 MAG make
#
#
#  -- 1830 FIC make
#
#
#  -- 1830 NF make
#
#
#  -- 1830 MAG make
#
#
#  -- 1840 FIC make
#
#
#  -- 1840 NF make
#
#
#  -- 1840 MAG make
#
#
#  -- 1850 FIC make
#
#
#  -- 1850 NF make
#
#
#  -- 1850 MAG make
#
#
#  -- 1860 FIC make
#
#
#  -- 1860 NF make
#
#
#  -- 1860 MAG make
#
#
#  -- 1870 FIC make
#
#
#  -- 1870 NF make
#
#
#  -- 1870 MAG make
#
#
#  -- 1880 FIC make
#
#
#  -- 1880 NF make
#
#
#  -- 1880 MAG make
#
#
#  -- 1890 FIC make
#
#
#  -- 1890 NF make
#
#
#  -- 1890 MAG make
#
#
#  -- 1900 FIC make
#
#
#  -- 1900 NF make
#
#
#  -- 1900 MAG make
#
#
#  -- 1910 FIC make
#
#
#  -- 1910 NF make
#
#
#  -- 1910 MAG make
#
#
#  -- 1920 FIC make
#
#
#  -- 1920 NF make
#
#
#  -- 1920 MAG make
#
#
#  -- 1930 FIC make
#
#
#  -- 1930 NF make
#
#
#  -- 1930 MAG make
#
#
#  -- 1940 FIC make
#
#
#  -- 1940 NF make
#
#
#  -- 1940 MAG make
#
#
#  -- 1950 FIC make
#
#
#  -- 1950 NF make
#
#
#  -- 1950 MAG make
#
#
#  -- 1960 FIC make
#
#
#  -- 1960 NF make
#
#
#  -- 1960 MAG make
#
#
#  -- 1970 FIC make
#
#
#  -- 1970 NF make
#
#
#  -- 1970 MAG make
#
#
#  -- 1980 FIC make
#
#
#  -- 1980 NF make
#
#
#  -- 1980 MAG make
#
#
#  -- 1990 FIC make
#
#
#  -- 1990 NF make
#
#
#  -- 1990 MAG make
#
#
#  -- 2000 FIC make
#
#
#  -- 2000 NF make
#
#
#  -- 2000 MAG make
#
#
#  -- 1820 FIC take
#
#
#  -- 1820 NF take
#
#
#  -- 1820 MAG take
#
#
#  -- 1830 FIC take
#
#
#  -- 1830 NF take
#
#
#  -- 1830 MAG take
#
#
#  -- 1840 FIC take
#
#
#  -- 1840 NF take
#
#
#  -- 1840 MAG take
#
#
#  -- 1850 FIC take
#
#
#  -- 1850 NF take
#
#
#  -- 1850 MAG take
#
#
#  -- 1860 FIC take
#
#
#  -- 1860 NF take
#
#
#  -- 1860 MAG take
#
#
#  -- 1870 FIC take
#
#
#  -- 1870 NF take
#
#
#  -- 1870 MAG take
#
#
#  -- 1880 FIC take
#
#
#  -- 1880 NF take
#
#
#  -- 1880 MAG take
#
#
#  -- 1890 FIC take
#
#
#  -- 1890 NF take
#
#
#  -- 1890 MAG take
#
#
#  -- 1900 FIC take
#
#
#  -- 1900 NF take
#
#
#  -- 1900 MAG take
#
#
#  -- 1910 FIC take
#
#
#  -- 1910 NF take
#
#
#  -- 1910 MAG take
#
#
#  -- 1920 FIC take
#
#
#  -- 1920 NF take
#
#
#  -- 1920 MAG take
#
#
#  -- 1930 FIC take
#
#
#  -- 1930 NF take
#
#
#  -- 1930 MAG take
#
#
#  -- 1940 FIC take
#
#
#  -- 1940 NF take
#
#
#  -- 1940 MAG take
#
#
#  -- 1950 FIC take
#
#
#  -- 1950 NF take
#
#
#  -- 1950 MAG take
#
#
#  -- 1960 FIC take
#
#
#  -- 1960 NF take
#
#
#  -- 1960 MAG take
#
#
#  -- 1970 FIC take
#
#
#  -- 1970 NF take
#
#
#  -- 1970 MAG take
#
#
#  -- 1980 FIC take
#
#
#  -- 1980 NF take
#
#
#  -- 1980 MAG take
#
#
#  -- 1990 FIC take
#
#
#  -- 1990 NF take
#
#
#  -- 1990 MAG take
#
#
#  -- 2000 FIC take
#
#
#  -- 2000 NF take
#
#
#  -- 2000 MAG take
#
#
#  -- 1820 FIC give
#
#
#  -- 1820 NF give
#
#
#  -- 1820 MAG give
#
#
#  -- 1830 FIC give
#
#
#  -- 1830 NF give
#
#
#  -- 1830 MAG give
#
#
#  -- 1840 FIC give
#
#
#  -- 1840 NF give
#
#
#  -- 1840 MAG give
#
#
#  -- 1850 FIC give
#
#
#  -- 1850 NF give
#
#
#  -- 1850 MAG give
#
#
#  -- 1860 FIC give
#
#
#  -- 1860 NF give
#
#
#  -- 1860 MAG give
#
#
#  -- 1870 FIC give
#
#
#  -- 1870 NF give
#
#
#  -- 1870 MAG give
#
#
#  -- 1880 FIC give
#
#
#  -- 1880 NF give
#
#
#  -- 1880 MAG give
#
#
#  -- 1890 FIC give
#
#
#  -- 1890 NF give
#
#
#  -- 1890 MAG give
#
#
#  -- 1900 FIC give
#
#
#  -- 1900 NF give
#
#
#  -- 1900 MAG give
#
#
#  -- 1910 FIC give
#
#
#  -- 1910 NF give
#
#
#  -- 1910 MAG give
#
#
#  -- 1920 FIC give
#
#
#  -- 1920 NF give
#
#
#  -- 1920 MAG give
#
#
#  -- 1930 FIC give
#
#
#  -- 1930 NF give
#
#
#  -- 1930 MAG give
#
#
#  -- 1940 FIC give
#
#
#  -- 1940 NF give
#
#
#  -- 1940 MAG give
#
#
#  -- 1950 FIC give
#
#
#  -- 1950 NF give
#
#
#  -- 1950 MAG give
#
#
#  -- 1960 FIC give
#
#
#  -- 1960 NF give
#
#
#  -- 1960 MAG give
#
#
#  -- 1970 FIC give
#
#
#  -- 1970 NF give
#
#
#  -- 1970 MAG give
#
#
#  -- 1980 FIC give
#
#
#  -- 1980 NF give
#
#
#  -- 1980 MAG give
#
#
#  -- 1990 FIC give
#
#
#  -- 1990 NF give
#
#
#  -- 1990 MAG give
#
#
#  -- 2000 FIC give
#
#
#  -- 2000 NF give
#
#
#  -- 2000 MAG give

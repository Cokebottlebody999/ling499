# %%
import re

# %%
import pandas

# %%
files = ["noun.act", "noun.cognition", "noun.communication","noun.event", "noun.feeling", "noun.location", "noun.motive", "noun.phenomenon", "noun.possession", "noun.process", "noun.relation", "noun.state"]
for f in files:
    print(f)
# Out:
# noun.act
# noun.cognition
# noun.communication
# noun.event
# noun.feeling
# noun.location
# noun.motive
# noun.phenomenon
# noun.possession
# noun.process
# noun.relation
# noun.state

# %%
wordsArray = []
i = -1
for file in files:
    with open(file) as f:
        for l in f:
            if "[" in l:
                p = re.compile('\[(.*)\]')
                matches = p.findall(l)
                for match in matches:
                    p2 = re.compile("([^,]+)")
                    matches2 = p2.findall(match)
                    for match2 in matches2:
                        result = re.sub(r'[0-9]+', '', match2)
                        result = re.sub(r'\+', '', result)
                        result = re.sub(r'\]', '', result)
                        result = re.sub(r'\[', '', result)
                        result = re.sub(r' ', '', result)
                        result = re.sub(r'!', '', result)
#                         print(result)
                        if "." not in result and result is not "":
                            i = i + 1
                            wordsArray.append([result])
                        elif "verb" in result and (result.split(':')[1] not in wordsArray[i] or len(wordsArray[i]) < 2):
                            wordsArray[i].append(result.split(':')[1])
newWordArray = []
for word in wordsArray:
    if len(word) > 1:
        newWordArray.append(word)

# %%
print(found[1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-e9c85a3c2a0e> in <module>
# ----> 1 print(found[1])
#
# IndexError: list index out of range

# %%
import pandas as pd

# %%
df = pd.DataFrame(newWordArray)

# %%
df.to_csv("NounWithAVerbForm.csv",  index = False)

# %%
df = df.sort_values(by=[0])

# %%
df[0] = "[" + df[0].str.upper() + "]"

# %%
df
# Out:
#                        0             1         2     3
# 7860          [;RMIDDLE]        middle      None  None
# 2880          [;USNOOZE]        snooze      None  None
# 8324   [AMERICANISATION]   americanise      None  None
# 8323   [AMERICANIZATION]   americanize      None  None
# 8327     [ANGLICISATION]     anglicise      None  None
# 8326     [ANGLICIZATION]     anglicize      None  None
# 7084        [ASSUMPTION]        assume      None  None
# 5143              [CALL]          call      None  None
# 5165       [CATHOLICISM]   catholicize      None  None
# 2080        [CHARLESTON]    Charleston      None  None
# 7071  [CHRISTIANISATION]  Christianise      None  None
# 7070  [CHRISTIANIZATION]  Christianize      None  None
# 3410         [COMMUNION]       commune      None  None
# 900           [CREATION]        create      None  None
# 6090             [CROWN]         crown  coronate  None
# 3246           [CRUSADE]       crusade      None  None
# 8463   [EUROPEANISATION]   europeanise      None  None
# 8462   [EUROPEANIZATION]   europeanize      None  None
# 5620               [FTP]           FTP      None  None
# 7616              [FALL]          fall      None  None
# 5504            [GOOGLE]        google      None  None
# 5503          [MAPQUEST]      mapquest      None  None
# 5660                [OK]          O.K.      None  None
# 2215         [PRESIDENT]       preside      None  None
# 4367       [RESTORATION]       restore      None  None
# 8706     [STALINISATION]     stalinise      None  None
# 8705     [STALINIZATION]     stalinize      None  None
# 7086   [TRANSFIGURATION]   transfigure      None  None
# 3012          [X-RAYING]         x-ray      None  None
# 238        [ABANDONMENT]       abandon      None  None
# ...                  ...           ...       ...   ...
# 870          [WRITE-OFF]     write_off      None  None
# 5639          [WRITE_UP]      write_up      None  None
# 2225           [WRITING]         write      None  None
# 3100           [WRITING]         write      None  None
# 2486             [WRONG]         wrong      None  None
# 1292          [YACHTING]         yacht      None  None
# 6361              [YACK]          yack      None  None
# 6674              [YARN]          yarn      None  None
# 7404               [YAW]           yaw      None  None
# 2783              [YAWN]          yawn      None  None
# 2784           [YAWNING]          yawn      None  None
# 7636          [YEARNING]         yearn      None  None
# 6260              [YELL]          yell      None  None
# 6263              [YELL]          yell      None  None
# 6283           [YELLING]          yell      None  None
# 7362              [YELP]          yelp      None  None
# 7363           [YELPING]          yelp      None  None
# 7638               [YEN]           yen      None  None
# 8129             [YIELD]         yield      None  None
# 3047             [YIELD]         yield      None  None
# 6814          [YIELDING]         yield      None  None
# 6480          [YIELDING]         yield      None  None
# 6285             [YODEL]         yodel      None  None
# 4300          [YODELING]         yodel      None  None
# 6271              [YOWL]          yowl      None  None
# 4927              [ZERO]          zero      None  None
# 7847              [ZONE]          zone      None  None
# 7969              [ZONE]          zone      None  None
# 1363              [ZOOM]          zoom      None  None
# 7173              [ZOOM]          zoom      None  None
#
# [9467 rows x 4 columns]

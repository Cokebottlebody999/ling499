# %%
import datetime
import pandas as pd
import numpy as np

# %%
[make, take, give, bring, bear, lose, grant, create, hold, keep]

# %%
years = [1940]
genre = ["FIC", "NF", "MAG"]
d = pd.DataFrame()
results = pd.DataFrame()
results['lemma'] = []
for i in years:
    a = pd.read_csv("keep" + str(i) + "FIC.csv")
    b = pd.read_csv("keep" + str(i) + "NF.csv")
    c = pd.read_csv("keep" + str(i) + "MAG.csv")
    d = a.merge(b, on = ["lemma"], how='outer').merge(c, on = ["lemma"], how='outer')
    d[['count_x','count_y', 'count']] = d[['count_x','count_y', 'count']].fillna(0)
    d[str(i)] = d['count_x'] + d['count_y'] + d['count']
    d = d.drop(["count_x", "count_y", "count"],axis=1)
    d = d.dropna(subset=['lemma'])
    results = results.merge(d, on = ["lemma"], how='outer')
results = results.fillna(0)
results["sum"] = results.sum(axis=1)
sort = results.sort_values(by=['sum'], ascending=False)
sort['lemma'] = '[' + sort['lemma'].str.upper() + ']'
sort.to_csv("KEEP1940NewResults.csv", encoding='utf-8', index=False)
sort
# Out:
#                     lemma   1940    sum
# 0                   [EYE]  106.0  106.0
# 6                  [MIND]   49.0   49.0
# 3                [SECRET]   42.0   42.0
# 2                  [HEAD]   32.0   32.0
# 5                  [HAND]   31.0   31.0
# 1                 [MOUTH]   30.0   30.0
# 15                  [MAN]   28.0   28.0
# 9                   [WAY]   27.0   27.0
# 4                 [THING]   27.0   27.0
# 87               [RECORD]   24.0   24.0
# 23                [ORDER]   24.0   24.0
# 7                 [WATCH]   23.0   23.0
# 19              [COMPANY]   23.0   23.0
# 11                [RIGHT]   23.0   23.0
# 29                 [PACE]   22.0   22.0
# 51                  [WAR]   20.0   20.0
# 24                [PLACE]   20.0   20.0
# 14                [HOUSE]   20.0   20.0
# 17                  [RUN]   19.0   19.0
# 31               [PEOPLE]   18.0   18.0
# 50                [PEACE]   17.0   17.0
# 8                 [THINK]   16.0   16.0
# ...

# %%
# Out:
#                lemma   1940    sum
# 4              [MAN]  154.0  154.0
# 6            [MONEY]  133.0  133.0
# 1             [MIND]  131.0  131.0
# 2          [MISTAKE]  122.0  122.0
# 3              [WAY]  121.0  121.0
# 44             [USE]  115.0  115.0
# 7       [DIFFERENCE]  108.0  108.0
# 11          [EFFORT]  103.0  103.0
# 558          [PAPER]   95.0   95.0
# 0          [GESTURE]   94.0   94.0
# 5            [THING]   90.0   90.0
# 15        [DECISION]   82.0   82.0
# 20          [PEOPLE]   74.0   74.0
# 32            [TRIP]   68.0   68.0
# 27          [SPEECH]   67.0   67.0
# 21       [STATEMENT]   64.0   64.0
# 8            [SENSE]   63.0   63.0
# 25           [POINT]   61.0   61.0
# 94             [WAR]   60.0   60.0
# 9            [NOISE]   57.0   57.0
# 71      [APPEARANCE]   56.0   56.0
# 23           [WORLD]   55.0   55.0
# 38          [CHANGE]   54.0   54.0
# 83            [HOME]   54.0   54.0
# 82            [WORK]   54.0   54.0
# 35          [LIVING]   53.0   53.0
# ...

# %%
sort.to_csv("1940newResults.csv", encoding='utf-8', index=False)

# %%
years = [1820, 1830, 1840, 1850, 1860, 1870, 1880, 1890, 1900, 1910, 1920, 1930, 1940, 1950, 1960, 1970, 1980, 1990, 2000]
genre = ["FIC", "NF", "MAG"]
d = pd.DataFrame()
results = pd.DataFrame()
results['lemma'] = []
for i in years:
    a = pd.read_csv("give" + str(i) + "MAG.csv")
#     d = a.merge(b, on = ["lemma"], how='outer').merge(c, on = ["lemma"], how='outer')
    a['count']= a['count'].fillna(0)
    a[str(i)] = a['count']
    a = a.drop(["count"],axis=1)
    a = a.dropna(subset=['lemma'])
    results = results.merge(a, on = ["lemma"], how='outer')
results = results.fillna(0)
results["sum"] = results.sum(axis=1)
sort = results.sort_values(by=['sum'], ascending=False)
sort['lemma'] = '[' + sort['lemma'].str.upper() + ']'
sort
# Out:
#                lemma  1820  1830  1840  1850  1860  1870  1880  1890  1900  \
# 1              [WAY]  40.0  33.0  38.0  26.0  49.0  61.0  56.0  49.0  35.0
# 14           [POWER]  19.0  30.0  33.0  44.0  28.0  37.0  31.0  32.0  19.0
# 0          [ACCOUNT]  52.0  76.0  52.0  45.0  27.0  31.0  24.0  30.0  36.0
# 5             [NAME]  27.0  31.0  19.0  22.0  23.0  31.0  41.0  24.0  30.0
# 96          [CHANCE]   6.0   2.0   3.0   4.0   9.0  17.0   9.0  18.0  20.0
# 42             [MAN]  11.0  28.0  28.0  26.0  28.0  35.0  28.0  52.0  21.0
# 2             [RISE]  36.0  32.0  36.0  24.0  39.0  33.0  27.0  30.0  27.0
# 4             [IDEA]  30.0  32.0  34.0  24.0  22.0  34.0  23.0  18.0  20.0
# 33           [PLACE]  12.0  27.0  36.0  48.0  21.0  24.0  32.0  36.0  33.0
# 10     [OPPORTUNITY]  21.0  13.0  21.0  18.0  19.0  17.0  28.0  27.0  31.0
# 36            [LIFE]  11.0  11.0  31.0  23.0  22.0  20.0  28.0  24.0  15.0
# ...

# %%
sort.to_csv("GIVEMAG1820-2000results.csv", encoding='utf-8', index=False)
